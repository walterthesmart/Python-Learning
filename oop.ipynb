# %%
from bank_account import *

Walter = BankAccount(2500, "Walter")
Shade = BankAccount(1500, "Shade")

Walter.getBalance()
Shade.getBalance()

Walter.deposit(1300)
Shade.deposit(5000)

Walter.withdraw(300)
Shade.withdraw(3400)

Walter.transfer(1200, Shade)

Chibuzor = InterestRewardsAcct(4000, "Chibuzor")
Chibuzor.deposit(200)
Chibuzor.getBalance()
Chibuzor.transfer(50, Walter)


Joy = SavingsAcct(3000, "Joy")
Joy.getBalance()
Joy.deposit(300)
Joy.transfer(500, Walter)
# Out:
# Account 'Walter' created.
# Balance = $2500.00
#
# Account 'Shade' created.
# Balance = $1500.00
#
# Account 'Walter' balance = $2500.00
#
# Account 'Shade' balance = $1500.00
#
# Deposit complete
#
# Account 'Walter' balance = $3800.00
#
# Deposit complete
#
# Account 'Shade' balance = $6500.00
#
# Withdraw complete
#
# Account 'Walter' balance = $3500.00
#
# Withdraw complete
#
# Account 'Shade' balance = $3100.00
#
# *************
#
# Beginning Transfer.....🚀🚀🚀
#
# Withdraw complete
#
# Account 'Walter' balance = $2300.00
#
# Deposit complete
#
# Account 'Shade' balance = $4300.00
#
# Transfer complete! ✅✅
#
# *************
#
# Account 'Chibuzor' created.
# Balance = $4000.00
#
# Deposit complete.
#
# Account 'Chibuzor' balance = $4210.00
#
# Account 'Chibuzor' balance = $4210.00
#
# *************
#
# Beginning Transfer.....🚀🚀🚀
#
# Withdraw complete
#
# Account 'Chibuzor' balance = $4160.00
#
# Deposit complete
#
# Account 'Walter' balance = $2350.00
#
# Transfer complete! ✅✅
#
# ...
